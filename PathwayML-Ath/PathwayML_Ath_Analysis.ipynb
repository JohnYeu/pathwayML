# %% [markdown]
# # PathwayML-Ath: Reproducible No-Embedding Analysis
#
# This notebook intentionally contains no stale saved outputs. Run the cell below to regenerate all tables, figures, selected GO terms, negative sets, train/test splits, and candidate scores from the canonical pipeline.

# %%
# %run run_no_embedding_reproducible.py

# %%
import json
from pathlib import Path
results = json.loads(Path('tables/results_no_embedding.json').read_text())
print('D =', results['dataset']['D'])
print('Selected GO =', results['dataset']['n_go_selected'])
print('XGBoost test AUROC =', results['performance']['XGBoost']['test_auroc'])
print('Candidate results:')
for row in results['candidates']:
    print(row['candidate'], 'score=', round(row['score'], 3), 'novel=', row['novel'])
